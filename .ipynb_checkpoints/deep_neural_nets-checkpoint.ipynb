# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# Load and preprocess data
data = pd.read_csv("RF_imputation_NEW.csv")
data.drop(columns=['deathtime', 'survival_time', 'LOS', 'Unnamed_0', 'V1', 'admittime', 'ID', 'group', 'tLOS', 'subject_id'], inplace=True)
data['outcome'] = data['outcome'].astype(int)
predictor_names = data.columns.difference(['outcome'])

# Function to preprocess data
def preprocess_data(data, predictor_names, random_seed):
    scaler = StandardScaler()
    data[predictor_names] = scaler.fit_transform(data[predictor_names])
    train_data, valid_data = train_test_split(data, test_size=0.3, random_state=random_seed)
    return train_data, valid_data

# Preprocess the data
train_data, valid_data = preprocess_data(data, predictor_names, random_seed=42)

X_train = train_data[predictor_names]
y_train = train_data['outcome']
X_valid = valid_data[predictor_names]
y_valid = valid_data['outcome']

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Define function to create the model
def create_model(learning_rate=0.001, dropout_rate=0.5, regularization=0.001):
    model = Sequential()
    model.add(Input(shape=(X_train_resampled.shape[1],)))
    model.add(Dense(512, activation='relu', kernel_regularizer=l2(regularization)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    model.add(Dense(256, activation='relu', kernel_regularizer=l2(regularization)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(regularization)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    model.add(Dense(64, activation='relu', kernel_regularizer=l2(regularization)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    model.add(Dense(32, activation='relu', kernel_regularizer=l2(regularization)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Hyperparameter tuning
best_auc = 0
best_params = {}

learning_rates = [0.001, 0.01, 0.1]
dropout_rates = [0.3, 0.5, 0.7]
regularizations = [0.001, 0.01, 0.1]
epochs_list = [50, 100]
batch_sizes = [16, 32, 64]

for lr in learning_rates:
    for dr in dropout_rates:
        for reg in regularizations:
            for epochs in epochs_list:
                for batch_size in batch_sizes:
                    print(f"Training model with lr={lr}, dr={dr}, reg={reg}, epochs={epochs}, batch_size={batch_size}")
                    model = create_model(learning_rate=lr, dropout_rate=dr, regularization=reg)
                    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
                    history = model.fit(X_train_resampled, y_train_resampled, validation_data=(X_valid, y_valid), epochs=epochs, batch_size=batch_size, callbacks=[early_stopping], verbose=0)
                    
                    y_pred_proba = model.predict(X_valid).ravel()
                    auc = roc_auc_score(y_valid, y_pred_proba)
                    print(f"AUC: {auc}")
                    
                    if auc > best_auc:
                        best_auc = auc
                        best_params = {
                            'learning_rate': lr,
                            'dropout_rate': dr,
                            'regularization': reg,
                            'epochs': epochs,
                            'batch_size': batch_size
                        }

print("Best AUC found: ", best_auc)
print("Best parameters found: ", best_params)

# Train the best model
model = create_model(learning_rate=best_params['learning_rate'], dropout_rate=best_params['dropout_rate'], regularization=best_params['regularization'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train_resampled, y_train_resampled, validation_data=(X_valid, y_valid), epochs=best_params['epochs'], batch_size=best_params['batch_size'], callbacks=[early_stopping])

# Evaluate the best model
y_pred_proba = model.predict(X_valid).ravel()
y_pred = (y_pred_proba > 0.5).astype(int)

print(classification_report(y_valid, y_pred, zero_division=0))

# Calculate AUC for the best model
auc_best = roc_auc_score(y_valid, y_pred_proba)
print(f"AUC for the best model: {auc_best}")

# Plot ROC curve for the best model
fpr_best, tpr_best, thresholds_best = roc_curve(y_valid, y_pred_proba)
plt.figure()
plt.plot(fpr_best, tpr_best, color='darkorange', lw=2, label=f'ROC curve (area = {auc_best:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Best DNN Model')
plt.legend(loc="lower right")
plt.show()
# Out:
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7328257948947604
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7643528884908195
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7721450962830273
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.722257053291536
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7630094043887147
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7771607702642185
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6858934169278996
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.6839229735781459
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6864308105687417
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.8224809673085535
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.735602328705777
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7442901925660546
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.729332736229288
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6986117330944916
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.754321540528437
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7004030452306313
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7706224809673086
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7653381101656963
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7658755038065382
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.748410210479176
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7402597402597403
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7706224809673085
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.774115539632781
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.748499776085983
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7451858486341245
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7628302731751007
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7653381101656963
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7843260188087773
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.787102552619794
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7562919838781909
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7652485445588894
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.78692342140618
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7523510971786834
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7395432154052843
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7143752798925213
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7182266009852217
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6205105239587998
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7596059113300493
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6606359158083296
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7668607254814152
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7547693685624719
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7471562919838781
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.74769368562472
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7737572772055531
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7718763994626063
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7969547693685625
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7748320644872368
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7560232870577698
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.826511419614868
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7506493506493507
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7715181370353784
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7683833407971339
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7541424093148231
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7304075235109717
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7439319301388267
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7209135691894313
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7071204657411555
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7026421854008061
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6875055978504255
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7671294223018361
# Training model with lr=0.01, dr=0.3, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7561128526645767
# Training model with lr=0.01, dr=0.3, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7373040752351097
# Training model with lr=0.01, dr=0.3, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7865651589789521
# Training model with lr=0.01, dr=0.3, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7919390953873712
# Training model with lr=0.01, dr=0.3, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.728437080161218
# Training model with lr=0.01, dr=0.3, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7861173309449172
# Training model with lr=0.01, dr=0.3, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7632781012091358
# Training model with lr=0.01, dr=0.3, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7598746081504701
# Training model with lr=0.01, dr=0.3, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7659650694133453
# Training model with lr=0.01, dr=0.3, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7234214061800269
# Training model with lr=0.01, dr=0.3, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.747514554411106
# Training model with lr=0.01, dr=0.3, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7978504254366324
# Training model with lr=0.01, dr=0.5, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7548589341692791
# Training model with lr=0.01, dr=0.5, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7942678011643529
# Training model with lr=0.01, dr=0.5, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7924764890282131
# Training model with lr=0.01, dr=0.5, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.8174652933273623
# Training model with lr=0.01, dr=0.5, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7467980295566502
# Training model with lr=0.01, dr=0.5, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.728168383340797
# Training model with lr=0.01, dr=0.5, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7728616211374832
# Training model with lr=0.01, dr=0.5, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.767039856695029
# Training model with lr=0.01, dr=0.5, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7539632781012092
# Training model with lr=0.01, dr=0.5, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7691894312583968
# Training model with lr=0.01, dr=0.5, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7253918495297805
# Training model with lr=0.01, dr=0.5, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.8036721898790864
# Training model with lr=0.01, dr=0.5, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7533363188535601
# Training model with lr=0.01, dr=0.5, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7475145544111061
# Training model with lr=0.01, dr=0.5, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7141961486789073
# Training model with lr=0.01, dr=0.5, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7480519480519481
# Training model with lr=0.01, dr=0.5, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7831616659202865
# Training model with lr=0.01, dr=0.5, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7914017017465294
# Training model with lr=0.01, dr=0.7, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7997313031795791
# Training model with lr=0.01, dr=0.7, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7281683833407971
# Training model with lr=0.01, dr=0.7, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7813703537841468
# Training model with lr=0.01, dr=0.7, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7570085087326467
# Training model with lr=0.01, dr=0.7, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.8039408866995075
# Training model with lr=0.01, dr=0.7, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.793013882669055
# Training model with lr=0.01, dr=0.7, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7843260188087774
# Training model with lr=0.01, dr=0.7, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7365875503806538
# Training model with lr=0.01, dr=0.7, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.8082400358262427
# Training model with lr=0.01, dr=0.7, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.799373040752351
# Training model with lr=0.01, dr=0.7, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7820868786386027
# Training model with lr=0.01, dr=0.7, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7463502015226153
# Training model with lr=0.01, dr=0.7, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7628302731751008
# Training model with lr=0.01, dr=0.7, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7904164800716524
# Training model with lr=0.01, dr=0.7, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7929243170622481
# Training model with lr=0.01, dr=0.7, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7768920734437976
# Training model with lr=0.01, dr=0.7, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.8159426780116436
# Training model with lr=0.01, dr=0.7, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7871921182266008
# Training model with lr=0.1, dr=0.3, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.8334975369458127
# Training model with lr=0.1, dr=0.3, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.8105687416032243
# Training model with lr=0.1, dr=0.3, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.768472906403941
# Training model with lr=0.1, dr=0.3, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7690103000447827
# Training model with lr=0.1, dr=0.3, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.8175548589341692
# Training model with lr=0.1, dr=0.3, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7880877742946709
# Training model with lr=0.1, dr=0.3, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.6995073891625615
# Training model with lr=0.1, dr=0.3, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.79346171070309
# Training model with lr=0.1, dr=0.3, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.786833855799373
# Training model with lr=0.1, dr=0.3, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6728168383340797
# Training model with lr=0.1, dr=0.3, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7563815494849977
# Training model with lr=0.1, dr=0.3, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7583519928347514
# Training model with lr=0.1, dr=0.3, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7515450067174205
# Training model with lr=0.1, dr=0.3, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7040752351097179
# Training model with lr=0.1, dr=0.3, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.8091356918943126
# Training model with lr=0.1, dr=0.3, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6938647559337214
# Training model with lr=0.1, dr=0.3, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.4610837438423645
# Training model with lr=0.1, dr=0.3, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7826242722794448
# Training model with lr=0.1, dr=0.5, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7392745185848634
# Training model with lr=0.1, dr=0.5, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.8368114643976713
# Training model with lr=0.1, dr=0.5, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7859381997313033
# Training model with lr=0.1, dr=0.5, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7182266009852217
# Training model with lr=0.1, dr=0.5, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7687416032243619
# Training model with lr=0.1, dr=0.5, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7618450515002239
# Training model with lr=0.1, dr=0.5, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.5570085087326467
# Training model with lr=0.1, dr=0.5, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7373936408419167
# Training model with lr=0.1, dr=0.5, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7380206000895656
# Training model with lr=0.1, dr=0.5, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6137483206448724
# Training model with lr=0.1, dr=0.5, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7805642633228841
# Training model with lr=0.1, dr=0.5, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7004030452306315
# Training model with lr=0.1, dr=0.5, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7539632781012091
# Training model with lr=0.1, dr=0.5, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.6727272727272727
# Training model with lr=0.1, dr=0.5, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7012987012987012
# Training model with lr=0.1, dr=0.5, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6249888042991492
# Training model with lr=0.1, dr=0.5, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.651768920734438
# Training model with lr=0.1, dr=0.5, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7754590237348858
# Training model with lr=0.1, dr=0.7, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.593730407523511
# Training model with lr=0.1, dr=0.7, reg=0.001, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step
# AUC: 0.43860277653381097
# Training model with lr=0.1, dr=0.7, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7202866099417824
# Training model with lr=0.1, dr=0.7, reg=0.001, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7149126735333631
# Training model with lr=0.1, dr=0.7, reg=0.001, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7633676668159427
# Training model with lr=0.1, dr=0.7, reg=0.001, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7701746529332736
# Training model with lr=0.1, dr=0.7, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.3459023734885804
# Training model with lr=0.1, dr=0.7, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.5202866099417823
# Training model with lr=0.1, dr=0.7, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7064935064935065
# Training model with lr=0.1, dr=0.7, reg=0.01, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7039856695029109
# Training model with lr=0.1, dr=0.7, reg=0.01, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.3929690998656516
# Training model with lr=0.1, dr=0.7, reg=0.01, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6580385132109271
# Training model with lr=0.1, dr=0.7, reg=0.1, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.4037617554858934
# Training model with lr=0.1, dr=0.7, reg=0.1, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.4075235109717868
# Training model with lr=0.1, dr=0.7, reg=0.1, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.4484549932825796
# Training model with lr=0.1, dr=0.7, reg=0.1, epochs=100, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.6721003134796238
# Training model with lr=0.1, dr=0.7, reg=0.1, epochs=100, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.6723242274966412
# Training model with lr=0.1, dr=0.7, reg=0.1, epochs=100, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# AUC: 0.7195700850873264
# Best AUC found:  0.8368114643976713
# Best parameters found:  {'learning_rate': 0.1, 'dropout_rate': 0.5, 'regularization': 0.001, 'epochs': 50, 'batch_size': 32}
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5678 - loss: 17.5824 - val_accuracy: 0.5169 - val_loss: 8.9795
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6960 - loss: 5.5431 - val_accuracy: 0.5763 - val_loss: 2.9277
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7023 - loss: 2.9073 - val_accuracy: 0.6582 - val_loss: 3.2340
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6593 - loss: 2.8216 - val_accuracy: 0.6017 - val_loss: 3.0343
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7281 - loss: 2.8046 - val_accuracy: 0.7571 - val_loss: 3.1167
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7230 - loss: 3.2282 - val_accuracy: 0.4096 - val_loss: 3.6338
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7023 - loss: 3.0722 - val_accuracy: 0.7627 - val_loss: 2.6182
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6922 - loss: 2.8055 - val_accuracy: 0.7175 - val_loss: 3.2141
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6865 - loss: 3.1572 - val_accuracy: 0.6045 - val_loss: 3.2514
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7286 - loss: 2.9419 - val_accuracy: 0.5198 - val_loss: 3.0120
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6991 - loss: 2.8133 - val_accuracy: 0.5226 - val_loss: 3.1527
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6252 - loss: 3.1248 - val_accuracy: 0.7147 - val_loss: 2.4325
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6974 - loss: 2.6356 - val_accuracy: 0.4831 - val_loss: 4.0203
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6986 - loss: 3.7757 - val_accuracy: 0.5028 - val_loss: 3.6307
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6846 - loss: 2.9967 - val_accuracy: 0.7288 - val_loss: 2.7649
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6777 - loss: 2.9363 - val_accuracy: 0.6893 - val_loss: 2.9287
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6930 - loss: 2.6753 - val_accuracy: 0.5480 - val_loss: 3.6709
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6303 - loss: 3.0546 - val_accuracy: 0.8136 - val_loss: 2.5478
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6983 - loss: 2.7415 - val_accuracy: 0.6893 - val_loss: 2.3781
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6744 - loss: 2.6945 - val_accuracy: 0.7571 - val_loss: 3.5526
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6811 - loss: 3.4754 - val_accuracy: 0.7034 - val_loss: 2.9999
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6992 - loss: 2.7554 - val_accuracy: 0.7203 - val_loss: 3.2385
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6908 - loss: 2.7174 - val_accuracy: 0.6384 - val_loss: 2.1605
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6584 - loss: 2.5766 - val_accuracy: 0.4040 - val_loss: 3.1138
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6767 - loss: 2.5615 - val_accuracy: 0.5960 - val_loss: 3.1720
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6982 - loss: 2.8934 - val_accuracy: 0.8305 - val_loss: 2.6660
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6656 - loss: 2.8399 - val_accuracy: 0.8136 - val_loss: 3.1589
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6604 - loss: 3.1141 - val_accuracy: 0.9153 - val_loss: 2.3437
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6424 - loss: 4.8315 - val_accuracy: 0.7175 - val_loss: 5.4539
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6700 - loss: 4.2932 - val_accuracy: 0.3983 - val_loss: 3.1731
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6366 - loss: 3.4244 - val_accuracy: 0.4435 - val_loss: 3.0499
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6977 - loss: 2.7193 - val_accuracy: 0.7627 - val_loss: 2.7515
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7033 - loss: 3.0809 - val_accuracy: 0.6299 - val_loss: 3.8006
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.62      0.76       319
#            1       0.19      0.80      0.30        35
#
#     accuracy                           0.64       354
#    macro avg       0.58      0.71      0.53       354
# weighted avg       0.89      0.64      0.71       354
#
# AUC for the best model: 0.7828034034930587

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# Load and preprocess data
data = pd.read_csv("RF_imputation_NEW.csv")
data.drop(columns=['deathtime', 'survival_time', 'LOS', 'Unnamed_0', 'V1', 'admittime', 'ID', 'group', 'tLOS', 'subject_id'], inplace=True)
data['outcome'] = data['outcome'].astype(int)
predictor_names = data.columns.difference(['outcome'])

# Function to preprocess data
def preprocess_data(data, predictor_names, random_seed):
    scaler = StandardScaler()
    data[predictor_names] = scaler.fit_transform(data[predictor_names])
    train_data, valid_data = train_test_split(data, test_size=0.3, random_state=random_seed)
    return train_data, valid_data

# Preprocess the data
train_data, valid_data = preprocess_data(data, predictor_names, random_seed=42)

X_train = train_data[predictor_names]
y_train = train_data['outcome']
X_valid = valid_data[predictor_names]
y_valid = valid_data['outcome']

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Define the Residual Block
def residual_block(x, units, dropout_rate=0.5, regularization=0.001):
    shortcut = x
    x = Dense(units, activation='relu', kernel_regularizer=l2(regularization))(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(units, activation=None, kernel_regularizer=l2(regularization))(x)
    x = BatchNormalization()(x)
    x = Add()([shortcut, x])
    x = Dropout(dropout_rate)(x)
    x = Dense(units, activation='relu')(x)
    return x

# Define the ResNet model
def create_resnet_model(learning_rate=0.001, dropout_rate=0.5, regularization=0.001):
    inputs = Input(shape=(X_train_resampled.shape[1],))
    x = Dense(128, activation='relu', kernel_regularizer=l2(regularization))(inputs)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rate)(x)
    
    for _ in range(3):
        x = residual_block(x, 128, dropout_rate, regularization)
    
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Hyperparameter tuning
best_auc = 0
best_params = {}

learning_rates = [0.001, 0.01, 0.1]
dropout_rates = [0.3, 0.5, 0.7]
regularizations = [0.001, 0.01, 0.1]
epochs_list = [50, 100]
batch_sizes = [16, 32, 64]

for lr in learning_rates:
    for dr in dropout_rates:
        for reg in regularizations:
            for epochs in epochs_list:
                for batch_size in batch_sizes:
                    print(f"Training model with lr={lr}, dr={dr}, reg={reg}, epochs={epochs}, batch_size={batch_size}")
                    model = create_resnet_model(learning_rate=lr, dropout_rate=dr, regularization=reg)
                    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
                    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001, verbose=1)
                    history = model.fit(X_train_resampled, y_train_resampled, validation_data=(X_valid, y_valid), 
                                        epochs=epochs, batch_size=batch_size, callbacks=[early_stopping, reduce_lr], verbose=0)
                    
                    y_pred_proba = model.predict(X_valid).ravel()
                    auc = roc_auc_score(y_valid, y_pred_proba)
                    print(f"AUC: {auc}")
                    
                    if auc > best_auc:
                        best_auc = auc
                        best_params = {
                            'learning_rate': lr,
                            'dropout_rate': dr,
                            'regularization': reg,
                            'epochs': epochs,
                            'batch_size': batch_size
                        }

print("Best AUC found: ", best_auc)
print("Best parameters found: ", best_params)

# Train the best model
model = create_resnet_model(learning_rate=best_params['learning_rate'], 
                            dropout_rate=best_params['dropout_rate'], 
                            regularization=best_params['regularization'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001, verbose=1)
history = model.fit(X_train_resampled, y_train_resampled, validation_data=(X_valid, y_valid), 
                    epochs=best_params['epochs'], batch_size=best_params['batch_size'], callbacks=[early_stopping, reduce_lr])

# Evaluate the best model
y_pred_proba_final = model.predict(X_valid).ravel()
y_pred_final = (y_pred_proba_final > 0.5).astype(int)

print(classification_report(y_valid, y_pred_final, zero_division=0))

# Calculate AUC for the final model
auc_final = roc_auc_score(y_valid, y_pred_proba_final)
print(f"Final AUC: {auc_final}")

# Plot ROC curve for the final model
fpr_final, tpr_final, thresholds_final = roc_curve(y_valid, y_pred_proba_final)
plt.figure()
plt.plot(fpr_final, tpr_final, color='darkorange', lw=2, label=f'ROC curve (area = {auc_final:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Final ResNet Model')
plt.legend(loc="lower right")
plt.show()
# Out:
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=50, batch_size=16
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7564711150918048
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=50, batch_size=32
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7775190326914465
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=50, batch_size=64
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7739364084191671
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=100, batch_size=16
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7705329153605015
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=100, batch_size=32
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.774563367666816
# Training model with lr=0.001, dr=0.3, reg=0.001, epochs=100, batch_size=64
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7498432601880877
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=50, batch_size=16
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7616659202866098
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=50, batch_size=32
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7038961038961038
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# AUC: 0.7731303179579041
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=100, batch_size=16
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# AUC: 0.7261083743842365
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=100, batch_size=32
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7389162561576355
# Training model with lr=0.001, dr=0.3, reg=0.01, epochs=100, batch_size=64
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7616659202866098
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=50, batch_size=16
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7195700850873264
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=50, batch_size=32
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7541424093148231
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=50, batch_size=64
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# AUC: 0.7566502463054188
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=100, batch_size=16
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7079265562024183
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=100, batch_size=32
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7398119122257053
# Training model with lr=0.001, dr=0.3, reg=0.1, epochs=100, batch_size=64
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7223466188983431
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7364084191670399
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=50, batch_size=32
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.664128974473802
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7790416480071652
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=100, batch_size=16
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# AUC: 0.722884012539185
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=100, batch_size=32
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7596059113300493
# Training model with lr=0.001, dr=0.5, reg=0.001, epochs=100, batch_size=64
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.6104791759964173
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=50, batch_size=16
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.754679802955665
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# AUC: 0.7536050156739811
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=50, batch_size=64
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7696372592924318
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=100, batch_size=16
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7256605463502015
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=100, batch_size=32
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7655172413793103
# Training model with lr=0.001, dr=0.5, reg=0.01, epochs=100, batch_size=64
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7472458575906851
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=50, batch_size=16
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7377519032691446
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=50, batch_size=32
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7327810120913568
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=50, batch_size=64
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7665920286609942
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=100, batch_size=16
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7205553067622033
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=100, batch_size=32
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.781012091356919
# Training model with lr=0.001, dr=0.5, reg=0.1, epochs=100, batch_size=64
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.747872816838334
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=50, batch_size=16
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.5123152709359606
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=50, batch_size=32
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.6154948499776086
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=50, batch_size=64
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.5684729064039409
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=100, batch_size=16
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7622033139274519
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=100, batch_size=32
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.48795342588446033
# Training model with lr=0.001, dr=0.7, reg=0.001, epochs=100, batch_size=64
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.61307657859382
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=50, batch_size=16
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# AUC: 0.7587998208687863
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=50, batch_size=32
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# AUC: 0.7585311240483654
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=50, batch_size=64
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7641737572772056
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=100, batch_size=16
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7357814599193909
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=100, batch_size=32
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7321092700403046
# Training model with lr=0.001, dr=0.7, reg=0.01, epochs=100, batch_size=64
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7587102552619795
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=50, batch_size=16
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7359605911330049
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=50, batch_size=32
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7575459023734886
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=50, batch_size=64
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# AUC: 0.7339901477832512
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=100, batch_size=16
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7378414688759516
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=100, batch_size=32
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7371249440214958
# Training model with lr=0.001, dr=0.7, reg=0.1, epochs=100, batch_size=64
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7440214957456337
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=50, batch_size=16
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7663233318405732
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=50, batch_size=32
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7561128526645768
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=50, batch_size=64
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7551276309896999
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=100, batch_size=16
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7433049708911779
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=100, batch_size=32
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7493954321540528
# Training model with lr=0.01, dr=0.3, reg=0.001, epochs=100, batch_size=64
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# AUC: 0.7952530228392297
# Training model with lr=0.01, dr=0.3, reg=0.01, epochs=50, batch_size=16
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# AUC: 0.7678459471562921
# Training model with lr=0.01, dr=0.3, reg=0.01, epochs=50, batch_size=32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 86
#      84 early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
#      85 reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001, verbose=1)
# ---> 86 history = model.fit(X_train_resampled, y_train_resampled, validation_data=(X_valid, y_valid),
#      87                     epochs=epochs, batch_size=batch_size, callbacks=[early_stopping, reduce_lr], verbose=0)
#      89 y_pred_proba = model.predict(X_valid).ravel()
#      90 auc = roc_auc_score(y_valid, y_pred_proba)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 for step, iterator in epoch_iterator.enumerate_epoch():
#     317     callbacks.on_train_batch_begin(step)
# --> 318     logs = self.train_function(iterator)
#     319     logs = self._pythonify_logs(logs)
#     320     callbacks.on_train_batch_end(step, logs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### new CNN-LSTM

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Conv1D, Flatten, MaxPooling1D, Input, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import keras_tuner as kt

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Load and preprocess data
data = pd.read_csv("RF_imputation_NEW.csv")
data.drop(columns=['deathtime', 'survival_time', 'LOS', 'Unnamed_0', 'V1', 'admittime', 'ID', 'group', 'tLOS', 'subject_id'], inplace=True)
data['outcome'] = data['outcome'].astype(int)
predictor_names = data.columns.difference(['outcome'])

# Function to preprocess data
def preprocess_data(data, predictor_names, random_seed):
    scaler = StandardScaler()
    data[predictor_names] = scaler.fit_transform(data[predictor_names])
    train_data, valid_data = train_test_split(data, test_size=0.3, random_state=random_seed)
    return train_data, valid_data

# Preprocess the data
train_data, valid_data = preprocess_data(data, predictor_names, random_seed=42)

X_train = train_data[predictor_names].values
y_train = train_data['outcome'].values
X_valid = valid_data[predictor_names].values
y_valid = valid_data['outcome'].values

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Reshape data for Conv1D and LSTM
X_train_resampled = X_train_resampled.reshape((X_train_resampled.shape[0], X_train_resampled.shape[1], 1))
X_valid = X_valid.reshape((X_valid.shape[0], X_valid.shape[1], 1))

# Define the CNN-LSTM model
def build_model(hp):
    model = Sequential()
    model.add(Input(shape=(X_train_resampled.shape[1], 1)))
    
    for i in range(hp.Int('num_conv_layers', 1, 3)):
        model.add(Conv1D(filters=hp.Int(f'conv_{i}_filters', 32, 128, step=32), 
                         kernel_size=hp.Int(f'conv_{i}_kernel_size', 3, 5), 
                         activation='relu', kernel_regularizer=l2(hp.Float(f'conv_{i}_l2', 0.001, 0.01, sampling='log'))))
        model.add(BatchNormalization())
        model.add(MaxPooling1D(pool_size=2))
        model.add(Dropout(hp.Float(f'conv_{i}_dropout', 0.3, 0.7, step=0.1)))
    
    model.add(LSTM(128, return_sequences=True))
    model.add(Dropout(hp.Float('lstm_dropout', 0.3, 0.7, step=0.1)))
    model.add(LSTM(64))
    model.add(Dropout(hp.Float('lstm_dropout', 0.3, 0.7, step=0.1)))
    
    for i in range(hp.Int('num_dense_layers', 1, 3)):
        model.add(Dense(units=hp.Int(f'dense_{i}_units', 64, 256, step=64), 
                        activation='relu', kernel_regularizer=l2(hp.Float(f'dense_{i}_l2', 0.001, 0.01, sampling='log'))))
        model.add(BatchNormalization())
        model.add(Dropout(hp.Float(f'dense_{i}_dropout', 0.3, 0.7, step=0.1)))
    
    model.add(Dense(1, activation='sigmoid'))
    
    learning_rate = hp.Float('learning_rate', 1e-4, 1e-2, sampling='log')
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Initialize the tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=1,
    directory='my_dir',
    project_name='cnn_lstm_tuning'
)

# Perform hyperparameter tuning
tuner.search(
    X_train_resampled, y_train_resampled, 
    epochs=50, 
    validation_data=(X_valid, y_valid),
    callbacks=[EarlyStopping(monitor='val_loss', patience=10), 
               ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)]
)

# Get the optimal hyperparameters
best_hp = tuner.get_best_hyperparameters()[0]
print("Best Hyperparameters:", best_hp.values)

# Train the final model with the best hyperparameters
model = tuner.hypermodel.build(best_hp)
history = model.fit(
    X_train_resampled, y_train_resampled, 
    epochs=50, 
    validation_data=(X_valid, y_valid),
    callbacks=[EarlyStopping(monitor='val_loss', patience=10), 
               ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)]
)

# Evaluate the final model
y_pred_proba_final = model.predict(X_valid).ravel()
y_pred_final = (y_pred_proba_final > 0.5).astype(int)

print(classification_report(y_valid, y_pred_final, zero_division=0))

# Calculate AUC for the final model
auc_final = roc_auc_score(y_valid, y_pred_proba_final)
print(f"Final AUC: {auc_final}")

# Plot ROC curve for the final model
fpr_final, tpr_final, thresholds_final = roc_curve(y_valid, y_pred_proba_final)
plt.figure()
plt.plot(fpr_final, tpr_final, color='darkorange', lw=2, label=f'ROC curve (area = {auc_final:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Final CNN-LSTM Model')
plt.legend(loc="lower right")
plt.show()
# Out:
# Trial 10 Complete [00h 00m 37s]
# val_accuracy: 0.901129961013794
#
# Best val_accuracy So Far: 0.901129961013794
# Total elapsed time: 00h 03m 47s
# Best Hyperparameters: {'num_conv_layers': 1, 'conv_0_filters': 32, 'conv_0_kernel_size': 5, 'conv_0_l2': 0.003382124616200884, 'conv_0_dropout': 0.5, 'lstm_dropout': 0.3, 'num_dense_layers': 3, 'dense_0_units': 192, 'dense_0_l2': 0.0038149805319224565, 'dense_0_dropout': 0.4, 'learning_rate': 0.0006315792406669426, 'conv_1_filters': 128, 'conv_1_kernel_size': 5, 'conv_1_l2': 0.0025216554054427265, 'conv_1_dropout': 0.4, 'dense_1_units': 64, 'dense_1_l2': 0.001, 'dense_1_dropout': 0.3, 'dense_2_units': 64, 'dense_2_l2': 0.001, 'dense_2_dropout': 0.3}
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5137 - loss: 1.4628 - val_accuracy: 0.1102 - val_loss: 1.2400 - learning_rate: 6.3158e-04
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5513 - loss: 1.3550 - val_accuracy: 0.0989 - val_loss: 1.2705 - learning_rate: 6.3158e-04
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5459 - loss: 1.3508 - val_accuracy: 0.0989 - val_loss: 1.2689 - learning_rate: 6.3158e-04
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5284 - loss: 1.3195 - val_accuracy: 0.1073 - val_loss: 1.2976 - learning_rate: 6.3158e-04
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5446 - loss: 1.2800 - val_accuracy: 0.2203 - val_loss: 1.2474 - learning_rate: 6.3158e-04
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5419 - loss: 1.2523 - val_accuracy: 0.1582 - val_loss: 1.2810 - learning_rate: 6.3158e-04
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5738 - loss: 1.2236 - val_accuracy: 0.1977 - val_loss: 1.2599 - learning_rate: 3.1579e-04
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5402 - loss: 1.2268 - val_accuracy: 0.2458 - val_loss: 1.2953 - learning_rate: 3.1579e-04
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5485 - loss: 1.2301 - val_accuracy: 0.2881 - val_loss: 1.2901 - learning_rate: 3.1579e-04
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5256 - loss: 1.2307 - val_accuracy: 0.1582 - val_loss: 1.4301 - learning_rate: 3.1579e-04
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5713 - loss: 1.2030 - val_accuracy: 0.3277 - val_loss: 1.3392 - learning_rate: 3.1579e-04
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.27      0.42       319
#            1       0.11      0.86      0.20        35
#
#     accuracy                           0.33       354
#    macro avg       0.53      0.56      0.31       354
# weighted avg       0.86      0.33      0.40       354
#
# Final AUC: 0.535960591133005

# %% [markdown]
# ### Keras CNN

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Conv1D, Flatten, MaxPooling1D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
import keras_tuner as kt

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Load and preprocess data
data = pd.read_csv("RF_imputation_NEW.csv")
data.drop(columns=['deathtime', 'survival_time', 'LOS', 'Unnamed_0', 'V1', 'admittime', 'ID', 'group', 'tLOS', 'subject_id'], inplace=True)
data['outcome'] = data['outcome'].astype(int)
predictor_names = data.columns.difference(['outcome'])

# Function to preprocess data
def preprocess_data(data, predictor_names, random_seed):
    scaler = StandardScaler()
    data[predictor_names] = scaler.fit_transform(data[predictor_names])
    train_data, valid_data = train_test_split(data, test_size=0.3, random_state=random_seed)
    return train_data, valid_data

# Preprocess the data
train_data, valid_data = preprocess_data(data, predictor_names, random_seed=42)

X_train = train_data[predictor_names].values
y_train = train_data['outcome'].values
X_valid = valid_data[predictor_names].values
y_valid = valid_data['outcome'].values

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Reshape data for Conv1D
X_train_resampled = X_train_resampled.reshape((X_train_resampled.shape[0], X_train_resampled.shape[1], 1))
X_valid = X_valid.reshape((X_valid.shape[0], X_valid.shape[1], 1))

# Define the model building function for Keras Tuner
def build_model(hp):
    model = Sequential()
    model.add(Input(shape=(X_train_resampled.shape[1], 1)))
    for i in range(hp.Int('num_conv_layers', 1, 3)):
        model.add(Conv1D(filters=hp.Int(f'conv_{i}_filters', 32, 128, step=32), 
                         kernel_size=hp.Int(f'conv_{i}_kernel_size', 3, 5), 
                         activation='relu', kernel_regularizer=l2(hp.Float(f'conv_{i}_l2', 0.001, 0.01, sampling='log'))))
        model.add(BatchNormalization())
        model.add(MaxPooling1D(pool_size=2))
        model.add(Dropout(hp.Float(f'conv_{i}_dropout', 0.3, 0.7, step=0.1)))
    
    model.add(Flatten())
    
    for i in range(hp.Int('num_dense_layers', 1, 3)):
        model.add(Dense(units=hp.Int(f'dense_{i}_units', 64, 256, step=64), 
                        activation='relu', kernel_regularizer=l2(hp.Float(f'dense_{i}_l2', 0.001, 0.01, sampling='log'))))
        model.add(BatchNormalization())
        model.add(Dropout(hp.Float(f'dense_{i}_dropout', 0.3, 0.7, step=0.1)))
    
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(optimizer=Adam(learning_rate=hp.Float('learning_rate', 1e-4, 1e-2, sampling='log')), 
                  loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Initialize the tuner
tuner = kt.RandomSearch(build_model,
                        objective='val_accuracy',
                        max_trials=10,
                        executions_per_trial=1,
                        directory='my_dir',
                        project_name='cnn_tuning')

# Perform hyperparameter tuning
tuner.search(X_train_resampled, y_train_resampled, epochs=50, validation_data=(X_valid, y_valid),
             callbacks=[EarlyStopping(monitor='val_loss', patience=10), 
                        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)])

# Get the optimal hyperparameters
best_hp = tuner.get_best_hyperparameters()[0]
print("Best Hyperparameters:", best_hp.values)

# Train the final model with the best hyperparameters
model = tuner.hypermodel.build(best_hp)
history = model.fit(X_train_resampled, y_train_resampled, epochs=50, validation_data=(X_valid, y_valid),
                    callbacks=[EarlyStopping(monitor='val_loss', patience=10), 
                               ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)])

# Evaluate the final model
y_pred_proba_final = model.predict(X_valid).ravel()
y_pred_final = (y_pred_proba_final > 0.5).astype(int)

print(classification_report(y_valid, y_pred_final, zero_division=0))

# Calculate AUC for the final model
auc_final = roc_auc_score(y_valid, y_pred_proba_final)
print(f"Final AUC: {auc_final}")

# Plot ROC curve for the final model
fpr_final, tpr_final, thresholds_final = roc_curve(y_valid, y_pred_proba_final)
plt.figure()
plt.plot(fpr_final, tpr_final, color='darkorange', lw=2, label=f'ROC curve (area = {auc_final:0.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Final CNN Model')
plt.legend(loc="lower right")
plt.show()
# Out:
# Trial 10 Complete [00h 00m 03s]
# val_accuracy: 0.4887005686759949
#
# Best val_accuracy So Far: 0.903954803943634
# Total elapsed time: 00h 04m 50s
# Best Hyperparameters: {'num_conv_layers': 3, 'conv_0_filters': 128, 'conv_0_kernel_size': 5, 'conv_0_l2': 0.007081395153291552, 'conv_0_dropout': 0.4, 'num_dense_layers': 1, 'dense_0_units': 256, 'dense_0_l2': 0.002209602970062476, 'dense_0_dropout': 0.6000000000000001, 'learning_rate': 0.0002759119939730754, 'conv_1_filters': 96, 'conv_1_kernel_size': 3, 'conv_1_l2': 0.008694328672939823, 'conv_1_dropout': 0.5, 'conv_2_filters': 32, 'conv_2_kernel_size': 5, 'conv_2_l2': 0.0022495139793638134, 'conv_2_dropout': 0.4, 'dense_1_units': 192, 'dense_1_l2': 0.002968871151904716, 'dense_1_dropout': 0.6000000000000001}
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5001 - loss: 2.3883 - val_accuracy: 0.1243 - val_loss: 2.0919 - learning_rate: 2.7591e-04
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5214 - loss: 2.4209 - val_accuracy: 0.2260 - val_loss: 2.0724 - learning_rate: 2.7591e-04
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5295 - loss: 2.3287 - val_accuracy: 0.1045 - val_loss: 2.1045 - learning_rate: 2.7591e-04
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5391 - loss: 2.3120 - val_accuracy: 0.0989 - val_loss: 2.1684 - learning_rate: 2.7591e-04
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5182 - loss: 2.3117 - val_accuracy: 0.1045 - val_loss: 2.1908 - learning_rate: 2.7591e-04
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5301 - loss: 2.2047 - val_accuracy: 0.1102 - val_loss: 2.2149 - learning_rate: 2.7591e-04
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5430 - loss: 2.2435 - val_accuracy: 0.1130 - val_loss: 2.2344 - learning_rate: 2.7591e-04
# Epoch 8/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5415 - loss: 2.2039 - val_accuracy: 0.1356 - val_loss: 2.2418 - learning_rate: 1.3796e-04
# Epoch 9/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5434 - loss: 2.2306 - val_accuracy: 0.1723 - val_loss: 2.1789 - learning_rate: 1.3796e-04
# Epoch 10/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5850 - loss: 2.1225 - val_accuracy: 0.2175 - val_loss: 2.1443 - learning_rate: 1.3796e-04
# Epoch 11/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6071 - loss: 2.0973 - val_accuracy: 0.2797 - val_loss: 2.0962 - learning_rate: 1.3796e-04
# Epoch 12/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5781 - loss: 2.1000 - val_accuracy: 0.3588 - val_loss: 2.0406 - learning_rate: 1.3796e-04
# Epoch 13/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5860 - loss: 2.0855 - val_accuracy: 0.4407 - val_loss: 1.9972 - learning_rate: 1.3796e-04
# Epoch 14/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5807 - loss: 2.0759 - val_accuracy: 0.5113 - val_loss: 1.9648 - learning_rate: 1.3796e-04
# Epoch 15/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5726 - loss: 2.0822 - val_accuracy: 0.4972 - val_loss: 1.9706 - learning_rate: 1.3796e-04
# Epoch 16/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5815 - loss: 2.0854 - val_accuracy: 0.5141 - val_loss: 1.9535 - learning_rate: 1.3796e-04
# Epoch 17/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6183 - loss: 2.0129 - val_accuracy: 0.5480 - val_loss: 1.9368 - learning_rate: 1.3796e-04
# Epoch 18/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6072 - loss: 2.0148 - val_accuracy: 0.5847 - val_loss: 1.9117 - learning_rate: 1.3796e-04
# Epoch 19/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5737 - loss: 2.0326 - val_accuracy: 0.5989 - val_loss: 1.8977 - learning_rate: 1.3796e-04
# Epoch 20/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6268 - loss: 1.9587 - val_accuracy: 0.5989 - val_loss: 1.8861 - learning_rate: 1.3796e-04
# Epoch 21/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5942 - loss: 1.9955 - val_accuracy: 0.6045 - val_loss: 1.8808 - learning_rate: 1.3796e-04
# Epoch 22/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5717 - loss: 2.0141 - val_accuracy: 0.6130 - val_loss: 1.8682 - learning_rate: 1.3796e-04
# Epoch 23/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6164 - loss: 1.9611 - val_accuracy: 0.6299 - val_loss: 1.8570 - learning_rate: 1.3796e-04
# Epoch 24/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6224 - loss: 1.9250 - val_accuracy: 0.6271 - val_loss: 1.8531 - learning_rate: 1.3796e-04
# Epoch 25/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6076 - loss: 1.9495 - val_accuracy: 0.6102 - val_loss: 1.8565 - learning_rate: 1.3796e-04
# Epoch 26/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6023 - loss: 1.9478 - val_accuracy: 0.6130 - val_loss: 1.8439 - learning_rate: 1.3796e-04
# Epoch 27/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6160 - loss: 1.9076 - val_accuracy: 0.6130 - val_loss: 1.8345 - learning_rate: 1.3796e-04
# Epoch 28/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6562 - loss: 1.8930 - val_accuracy: 0.6073 - val_loss: 1.8215 - learning_rate: 1.3796e-04
# Epoch 29/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6558 - loss: 1.8656 - val_accuracy: 0.6412 - val_loss: 1.7968 - learning_rate: 1.3796e-04
# Epoch 30/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6172 - loss: 1.8418 - val_accuracy: 0.6356 - val_loss: 1.7918 - learning_rate: 1.3796e-04
# Epoch 31/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6440 - loss: 1.8329 - val_accuracy: 0.6215 - val_loss: 1.7821 - learning_rate: 1.3796e-04
# Epoch 32/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6626 - loss: 1.7881 - val_accuracy: 0.6299 - val_loss: 1.7662 - learning_rate: 1.3796e-04
# Epoch 33/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6239 - loss: 1.8631 - val_accuracy: 0.6384 - val_loss: 1.7637 - learning_rate: 1.3796e-04
# Epoch 34/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6885 - loss: 1.7502 - val_accuracy: 0.6215 - val_loss: 1.7641 - learning_rate: 1.3796e-04
# Epoch 35/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6640 - loss: 1.8033 - val_accuracy: 0.6299 - val_loss: 1.7539 - learning_rate: 1.3796e-04
# Epoch 36/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6751 - loss: 1.7898 - val_accuracy: 0.6497 - val_loss: 1.7239 - learning_rate: 1.3796e-04
# Epoch 37/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6553 - loss: 1.7597 - val_accuracy: 0.6582 - val_loss: 1.7104 - learning_rate: 1.3796e-04
# Epoch 38/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6690 - loss: 1.7523 - val_accuracy: 0.6497 - val_loss: 1.7069 - learning_rate: 1.3796e-04
# Epoch 39/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7034 - loss: 1.6891 - val_accuracy: 0.6412 - val_loss: 1.7075 - learning_rate: 1.3796e-04
# Epoch 40/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6892 - loss: 1.7140 - val_accuracy: 0.6497 - val_loss: 1.6911 - learning_rate: 1.3796e-04
# Epoch 41/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6785 - loss: 1.6988 - val_accuracy: 0.6554 - val_loss: 1.6857 - learning_rate: 1.3796e-04
# Epoch 42/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6869 - loss: 1.7152 - val_accuracy: 0.6554 - val_loss: 1.6912 - learning_rate: 1.3796e-04
# Epoch 43/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6646 - loss: 1.7296 - val_accuracy: 0.6582 - val_loss: 1.6822 - learning_rate: 1.3796e-04
# Epoch 44/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7062 - loss: 1.6364 - val_accuracy: 0.6525 - val_loss: 1.6784 - learning_rate: 1.3796e-04
# Epoch 45/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7036 - loss: 1.6547 - val_accuracy: 0.6441 - val_loss: 1.6779 - learning_rate: 1.3796e-04
# Epoch 46/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7198 - loss: 1.6386 - val_accuracy: 0.6412 - val_loss: 1.6773 - learning_rate: 1.3796e-04
# Epoch 47/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7129 - loss: 1.6136 - val_accuracy: 0.6469 - val_loss: 1.6728 - learning_rate: 1.3796e-04
# Epoch 48/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7088 - loss: 1.6280 - val_accuracy: 0.6554 - val_loss: 1.6503 - learning_rate: 1.3796e-04
# Epoch 49/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7235 - loss: 1.5806 - val_accuracy: 0.6582 - val_loss: 1.6456 - learning_rate: 1.3796e-04
# Epoch 50/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7178 - loss: 1.5642 - val_accuracy: 0.6638 - val_loss: 1.6289 - learning_rate: 1.3796e-04
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.66      0.78       319
#            1       0.18      0.66      0.28        35
#
#     accuracy                           0.66       354
#    macro avg       0.56      0.66      0.53       354
# weighted avg       0.87      0.66      0.73       354
#
# Final AUC: 0.6735333631885356
